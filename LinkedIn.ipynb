# %%
from selenium import webdriver

# %%
# Creation of a new instance of Google Chrome
browser = webdriver.Chrome(executable_path='C:/Users/Samar/Desktop/4BI4/Scrapping/chromedriver.exe')

# %%
from bs4 import BeautifulSoup

# %%
# Navigating to profile
link = 'https://www.linkedin.com/company/esprit_2/people/' # Profile link which you want to scrape
browser.get(link) 
browser.implicitly_wait(1)

# %%
# Rendering of the page 
soup = BeautifulSoup(browser.page_source, 'lxml')

# %%
print(soup.prettify())
# Out:
# <html class="theme theme--mercado artdeco windows" lang="en">
#  <head>
#   <script async="" src="https://platform.linkedin.com/js/analytics.js">
#   </script>
#   <script type="application/javascript">
#    !function(i,n){void 0!==i.addEventListener&&void 0!==i.hidden&&(n.liVisibilityChangeListener=function(){i.hidden&&(n.liHasWindowHidden=!0)},i.addEventListener("visibilitychange",n.liVisibilityChangeListener))}(document,window);
#   </script>
#   <title>
#    (3) ESPRIT: People | LinkedIn
#   </title>
#   <meta charset="utf-8"/>
#   <meta content="IE=edge" http-equiv="X-UA-Compatible"/>
#   <meta class="mercado-icons-sprite" content="https://static-exp1.licdn.com/sc/h/3ki0iq40x0w1ti93600pfmk84" id="artdeco-icons/static/images/sprite-asset" name="asset-url"/>
#   <meta content="" name="description"/>
#   <meta content="notranslate" name="google"/>
#   <meta content="true" name="is-http2"/>
#   <meta content="voyager-web" name="service"/>
# ...

# %%
Profiles = soup.find_all(id="people-graph-bar-ember880")

# %%
Profiles
# Out:
# [<div class="artdeco-card p4 m2 org-people-bar-graph-module__geo-region" id="people-graph-bar-ember880">
#  <div aria-live="polite" class="insight-container">
#  <div class="insight-container__title">
#  <h4 class="t-16 t-bold t-black inline-block flex-1">
#            Where they live
#          </h4>
#  <button aria-label="Add any location" class="artdeco-button artdeco-button--muted artdeco-button--1 artdeco-button--tertiary ember-view org-people-bar-graph-module__add-search-facet" id="ember881" tabindex="0"> <li-icon aria-hidden="true" class="artdeco-button__icon" size="small" type="plus-icon"><svg class="mercado-match" data-supported-dps="16x16" fill="currentColor" focusable="false" height="16" viewbox="0 0 16 16" width="16" xmlns="http://www.w3.org/2000/svg">
#  <path d="M14 9H9v5H7V9H2V7h5V2h2v5h5z"></path>
#  </svg></li-icon>
#  <span class="artdeco-button__text">
#      Add
#  </span></button>
#  </div>
# ...

# %%
Pro = Profiles[0]

# %%
# Out:
# <div class="artdeco-carousel__content">
# <ul class="artdeco-carousel__slider ember-view" id="ember85" style="transform: translateX(0px);">
# <li class="artdeco-carousel__item active ember-view" data-item-index="0" id="ember86" style="width: 265.6px;"><div class="artdeco-carousel__item-container" data-test-display="display">
# <div class="artdeco-card p4 m2 org-people-bar-graph-module__geo-region" id="people-graph-bar-ember87">
# <div aria-live="polite" class="insight-container">
# <div class="insight-container__title">
# <h4 class="t-16 t-bold t-black inline-block flex-1">
#           Where they live
#         </h4>
# ...

# %%
print(Pro.prettify())
# Out:
# <div class="artdeco-carousel__content">
#  <ul class="artdeco-carousel__slider ember-view" id="ember197" style="transform: translateX(0px);">
#   <li class="artdeco-carousel__item active ember-view" data-item-index="0" id="ember198" style="width: 359px;">
#    <div class="artdeco-carousel__item-container" data-test-display="display">
#     <div class="artdeco-card p4 m2 org-people-bar-graph-module__geo-region" id="people-graph-bar-ember199">
#      <div aria-live="polite" class="insight-container">
#       <div class="insight-container__title">
#        <h4 class="t-16 t-bold t-black inline-block flex-1">
#         Where they live
#        </h4>
#        <button aria-label="Add any location" class="artdeco-button artdeco-button--muted artdeco-button--1 artdeco-button--tertiary ember-view org-people-bar-graph-module__add-search-facet" id="ember200" tabindex="0">
#         <li-icon aria-hidden="true" class="artdeco-button__icon" size="small" type="plus-icon">
# ...

# %%
wherehtyelive = Pro.select(".org-people-bar-graph-element__percentage-bar-info")

# %%
where = [pt.get_text() for pt in wherehtyelive]

# %%
where
# Out:
# ['\n690 Tunisia\n',
#  '\n116 Ariana Governorate, Tunisia\n',
#  '\n93 Tunis Governorate, Tunisia\n',
#  '\n40 Ben Arous Governorate, Tunisia\n',
#  '\n30 Nabeul Governorate, Tunisia\n',
#  '\n25 Kebili Governorate, Tunisia\n',
#  '\n24 Bizerte Governorate, Tunisia\n',
#  '\n17 France\n',
#  '\n16 Mannouba Governorate, Tunisia\n',
#  '\n11 Monastir Governorate, Tunisia\n',
#  '\n8 Paris Area, France\n',
#  '\n8 Netherlands\n',
#  '\n8 Kairouan Governorate, Tunisia\n',
#  '\n6 Sfax Governorate, Tunisia\n',
#  '\n6 Sousse Governorate, Tunisia\n']

# %%
NN = soup.find_all(id="people-graph-bar-ember877")

# %%
NN
# Out:
# [<div class="artdeco-card p4 m2 org-people-bar-graph-module__organization" id="people-graph-bar-ember877">
#  <div aria-live="polite" class="insight-container">
#  <div class="insight-container__title">
#  <h4 class="t-16 t-bold t-black inline-block flex-1">
#            Where they studied
#          </h4>
#  <button aria-label="Add any school" class="artdeco-button artdeco-button--muted artdeco-button--1 artdeco-button--tertiary ember-view org-people-bar-graph-module__add-search-facet" id="ember878" tabindex="0"> <li-icon aria-hidden="true" class="artdeco-button__icon" size="small" type="plus-icon"><svg class="mercado-match" data-supported-dps="16x16" fill="currentColor" focusable="false" height="16" viewbox="0 0 16 16" width="16" xmlns="http://www.w3.org/2000/svg">
#  <path d="M14 9H9v5H7V9H2V7h5V2h2v5h5z"></path>
#  </svg></li-icon>
#  <span class="artdeco-button__text">
#      Add
#  </span></button>
#  </div>
# ...

# %%
NNN = NN[0]

# %%
wheretheystudied = NNN.select(".org-people-bar-graph-element__percentage-bar-info")

# %%
whereTS = [pt.get_text() for pt in wheretheystudied]

# %%
whereTS
# Out:
# ["\n277 Ecole Supérieure Privée d'Ingénierie et de Technologies - ESPRIT\n",
#  "\n32 Ecole Nationale d'Ingénieurs de Tunis\n",
#  "\n19 ENSI - Ecole Nationale des Sciences de l'Informatique\n",
#  '\n14 INSAT - Institut National des Sciences Appliquées et de Technologie \n',
#  '\n10 Institut Supérieur de Gestion de Tunis\n',
#  "\n10 IPEIN - Institut Préparatoire aux Études d'Ingénieur de Nabeul\n",
#  '\n10 Higher Institute of Technological Studies of Nabeul\n',
#  '\n9 Institut Supérieur des Etudes Technologiques en Communications de Tunis\n',
#  "\n9 Institut supérieur d'informatique\n",
#  "\n8 SUP'COM\n",
#  '\n7 University of Tunis El Manar\n',
#  '\n7 Faculté des Sciences Mathématiques, Physiques et Naturelles de Tunis\n',
#  '\n6 Institut Supérieur des Arts Multimédia de la Manouba(ISAMM)\n',
#  '\n5 Pierre and Marie Curie University\n',
#  '\n5 Université de La Manouba\n']

# %%
# Navigating to profile
link = 'https://www.linkedin.com/company/esprit_2/people/' # Profile link which you want to scrape
browser.get(link) 
browser.implicitly_wait(1)

# %%
# Rendering of the page 
soup = BeautifulSoup(browser.page_source, 'lxml')

# %%
Profiles = soup.find_all(class_="artdeco-carousel__content")

# %%
Pro = Profiles[0]

# %%
print(Pro.prettify())
# Out:
# <div class="artdeco-carousel__content">
#  <ul class="artdeco-carousel__slider ember-view" id="ember85" style="transform: translateX(0px);">
#   <li class="artdeco-carousel__item active ember-view" data-item-index="0" id="ember86" style="width: 265.6px;">
#    <div class="artdeco-carousel__item-container" data-test-display="display">
#     <div class="artdeco-card p4 m2 org-people-bar-graph-module__geo-region" id="people-graph-bar-ember87">
#      <div aria-live="polite" class="insight-container">
#       <div class="insight-container__title">
#        <h4 class="t-16 t-bold t-black inline-block flex-1">
#         Where they live
#        </h4>
#        <button aria-label="Add any location" class="artdeco-button artdeco-button--muted artdeco-button--1 artdeco-button--tertiary ember-view org-people-bar-graph-module__add-search-facet" id="ember88" tabindex="0">
#         <li-icon aria-hidden="true" class="artdeco-button__icon" size="small" type="plus-icon">
# ...

# %%
x = soup.find_all(id="people-graph-bar-ember93")
# Out:
# [<div class="artdeco-card p4 m2 org-people-bar-graph-module__current-function" id="people-graph-bar-ember93">
#  <div aria-live="polite" class="insight-container">
#  <div class="insight-container__title">
#  <h4 class="t-16 t-bold t-black inline-block flex-1">
#            What they do
#          </h4>
#  <!-- --> </div>
#  <button aria-hidden="true" class="org-people-bar-graph-element mt2 text-align-left full-width org-people-bar-graph-element--is-selectable" tabindex="-1" type="button">
#  <div class="org-people-bar-graph-element__percentage-bar-info truncate full-width mt2 mb1 t-14 t-black--light t-normal">
#  <strong>448</strong> <span class="org-people-bar-graph-element__category">Education</span>
#  </div>
#  <svg class="org-people-bar-graph-element__percentage-bar-container block">
#  <rect class="org-people-bar-graph-element__percentage-bar-background" height="17" rx="2" ry="2" width="100%"></rect>
# ...

# %%
XX = x[0]

# %%
whattheydo = XX.select(".org-people-bar-graph-element")

# %%
wheretD = [pt.get_text() for pt in whattheydo]

# %%
wheretD
# Out:
# ['\n\n448 Education\n\n\n\n\n\n',
#  '\n\n192 Engineering\n\n\n\n\n\n',
#  '\n\n60 Information Technology\n\n\n\n\n\n',
#  '\n\n47 Administrative\n\n\n\n\n\n',
#  '\n\n38 Operations\n\n\n\n\n\n',
#  '\n\n34 Research\n\n\n\n\n\n',
#  '\n\n33 Business Development\n\n\n\n\n\n',
#  '\n\n15 Sales\n\n\n\n\n\n',
#  '\n\n14 Media and Communication\n\n\n\n\n\n',
#  '\n\n14 Community and Social Services\n\n\n\n\n\n',
#  '\n\n13 Program and Project Management\n\n\n\n\n\n',
#  '\n\n11 Human Resources\n\n\n\n\n\n',
#  '\n\n11 Arts and Design\n\n\n\n\n\n',
#  '\n\n9 Marketing\n\n\n\n\n\n',
#  '\n\n8 Accounting\n\n\n\n\n\n']

# %%
V = soup.find_all(id="people-graph-bar-ember612")

# %%
V
# Out:
# [<div class="artdeco-card p4 m2 org-people-bar-graph-module__skill-explicit" id="people-graph-bar-ember612">
#  <div aria-live="polite" class="insight-container">
#  <div class="insight-container__title">
#  <h4 class="t-16 t-bold t-black inline-block flex-1">
#            What they are skilled at
#          </h4>
#  <button aria-label="Add any skill" class="artdeco-button artdeco-button--muted artdeco-button--1 artdeco-button--tertiary ember-view org-people-bar-graph-module__add-search-facet" id="ember613" tabindex="0"> <li-icon aria-hidden="true" class="artdeco-button__icon" size="small" type="plus-icon"><svg class="mercado-match" data-supported-dps="16x16" fill="currentColor" focusable="false" height="16" viewbox="0 0 16 16" width="16" xmlns="http://www.w3.org/2000/svg">
#  <path d="M14 9H9v5H7V9H2V7h5V2h2v5h5z"></path>
#  </svg></li-icon>
#  <span class="artdeco-button__text">
#      Add
#  </span></button>
#  </div>
# ...

# %%
len(V)
# Out:
# 1

# %%
VV = V[0]

# %%
Skills = VV.select(".org-people-bar-graph-element")

# %%
THSkills = [pt.get_text() for pt in Skills]

# %%
THSkills
# Out:
# ['\n\n185 Java\n\n\n\n\n\n',
#  '\n\n137 JavaScript\n\n\n\n\n\n',
#  '\n\n135 PHP\n\n\n\n\n\n',
#  '\n\n133 C++\n\n\n\n\n\n',
#  '\n\n133 C (Programming Language)\n\n\n\n\n\n',
#  '\n\n129 MySQL\n\n\n\n\n\n',
#  '\n\n128 SQL\n\n\n\n\n\n',
#  '\n\n126 Microsoft Office\n\n\n\n\n\n',
#  '\n\n121 Project Management\n\n\n\n\n\n',
#  '\n\n103 HTML\n\n\n\n\n\n',
#  '\n\n94 Linux\n\n\n\n\n\n',
#  '\n\n90 Cascading Style Sheets (CSS)\n\n\n\n\n\n',
#  '\n\n85 Unified Modeling Language (UML)\n\n\n\n\n\n',
#  '\n\n84 Microsoft Excel\n\n\n\n\n\n',
#  '\n\n76 English\n\n\n\n\n\n']

# %%
F = soup.find_all(id="people-graph-bar-ember610")

# %%
FF =F[0]

# %%
Whattheystudied = FF.select(".org-people-bar-graph-element")

# %%
WTS = [pt.get_text() for pt in Whattheystudied]

# %%
WTS
# Out:
# ['\n\n148 Computer and Information Sciences and Support Services\n\n\n\n\n\n',
#  '\n\n66 Engineering\n\n\n\n\n\n',
#  '\n\n57 Mathematics\n\n\n\n\n\n',
#  '\n\n34 Computer Systems Networking and Telecommunications\n\n\n\n\n\n',
#  '\n\n27 Physics\n\n\n\n\n\n',
#  '\n\n25 Computer Software Engineering\n\n\n\n\n\n',
#  '\n\n24 Information Science/Studies\n\n\n\n\n\n',
#  '\n\n21 Computer Science\n\n\n\n\n\n',
#  '\n\n18 Information Technology\n\n\n\n\n\n',
#  '\n\n18 Business Administration and Management, General\n\n\n\n\n\n',
#  '\n\n17 Civil Engineering\n\n\n\n\n\n',
#  '\n\n16 Electromechanical Engineering\n\n\n\n\n\n',
#  '\n\n16 Computational Science\n\n\n\n\n\n',
#  '\n\n15 Computer Engineering\n\n\n\n\n\n',
#  '\n\n15 Electrical and Electronics Engineering\n\n\n\n\n\n']

# %%
import pandas as pd
About = pd.DataFrame.from_dict({
    "Where": where,
    "WhereTS" : whereTS,
    "whattheyDo": wheretD,
    "skills" : THSkills,
   
})
About.transpose()
# Out:
#                                                            0   \
# Where                                         \n690 Tunisia\n
# WhereTS     \n277 Ecole Supérieure Privée d'Ingénierie et ...
# whattheyDo                      \n\n448 Education\n\n\n\n\n\n
# skills                               \n\n185 Java\n\n\n\n\n\n
#
#                                                       1   \
# Where                \n116 Ariana Governorate, Tunisia\n
# WhereTS     \n32 Ecole Nationale d'Ingénieurs de Tunis\n
# whattheyDo               \n\n192 Engineering\n\n\n\n\n\n
# skills                    \n\n137 JavaScript\n\n\n\n\n\n
#
#                                                            2   \
# Where                       \n93 Tunis Governorate, Tunisia\n
# WhereTS     \n19 ENSI - Ecole Nationale des Sciences de l'...
# whattheyDo          \n\n60 Information Technology\n\n\n\n\n\n
# skills                                \n\n135 PHP\n\n\n\n\n\n
#
# ...

# %%
About.to_csv(r'C:\Users\Samar\Desktop\4BI4\Scrapping\About.csv', index=False,header=True, encoding='utf-8')
